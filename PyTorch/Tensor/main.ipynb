# %%
import torch

# create a scalar 
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %%
# vector
vector = torch.tensor([7,7])
vector
# Out:
# tensor([7, 7])

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
vector.dtype
# Out:
# torch.int64

# %%
vector.ndim
# Out:
# 1

# %%
# Matrix
matrix = torch.tensor([[7,8],
                       [9, 10]])
matrix
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
print(matrix.ndim)
print(matrix.shape)
print(matrix.dtype)
# Out:
# 2
# torch.Size([2, 2])
# torch.int64

# %%
#Tensor
tensor = torch.tensor([[[1,2,3],
                       [4,5,6],
                       [5,6,4]]])
tensor
# Out:
# tensor([[[1, 2, 3],
#          [4, 5, 6],
#          [5, 6, 4]]])

# %%
tensor.shape
# Out:
# torch.Size([1, 3, 3])

# %%
tensor.ndim
# Out:
# 3

# %%
tensor[0]
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6],
#         [5, 6, 4]])

# %%
# random tensors
random_tensor = torch.rand(2, 3, 4)
random_tensor
# Out:
# tensor([[[0.0086, 0.3686, 0.6087, 0.1378],
#          [0.3417, 0.1447, 0.5667, 0.2440],
#          [0.6279, 0.5583, 0.2700, 0.8381]],
#
#         [[0.6337, 0.3385, 0.8570, 0.5101],
#          [0.9548, 0.9132, 0.3001, 0.2009],
#          [0.9772, 0.6597, 0.6649, 0.9019]]])

# %%
random_tensor.ndim
# Out:
# 3
